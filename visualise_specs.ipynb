# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
#define a function to get log-melspectrograms of audio files
def show1(file):
    y,sr = librosa.load("H:/audio_data/"+file+".wav")
    
    five_sec = 5 * sr
    diff = abs(len(y) - five_sec)
    #if len >5 sec then slice wave
    if(len(y) > five_sec):
        st_slice = np.random.randint(diff)
        end_slice = len(y) - (diff - st_slice)
        y = y[st_slice:end_slice]
        
    #if len<5 sec then pad wave
    elif(len(y) < five_sec):
        st_pad = np.random.randint(diff)
        end_pad = diff - st_pad
        y = np.pad(y, (st_pad,end_pad), "constant")

    mel = librosa.feature.melspectrogram(y = y)
    #log_mel = librosa.amplitude_to_db(mel)
    log_mel = librosa.power_to_db(mel)
    mean = np.mean(log_mel)
    std = np.std(log_mel)
    log_mel = (log_mel - mean) / std
    plt.imshow(log_mel, aspect='auto', origin='lower')

# %%
def listen(file):
    return ipd.Audio("H:/molly_ted/"+file+".wav")

# %%
file1 = "rahul-clip468_3,2,2.5"
file2 = "saijal-set3-clip50_2.5,3,3"

# %%
show1(file1)

# %%
show1(file1)

# %%
listen(file1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
show(file2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-21f8bc54390d> in <module>()
# ----> 1 show(file2)
#
# NameError: name 'show' is not defined

# %%
listen(file2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9a79071e85b4> in <module>()
# ----> 1 listen(file2)
#
# NameError: name 'listen' is not defined

# %%
#continous lines or curves may represent fluent speech
#broken lines or curves may represent non-fluent speech
##bright curves or lines concentreted at the base denotes heavy voice 
##low intensity curves well separated denotes light voice

# %%
#i am trying to point out 2 things other than liveliness that are playing role inside spectrograms
#that are 'clarity' and 'speech rate'
#they may have some correlation with liveliness, so we have to observe the differences between specs of clear and unclear, fast and slow
#speeches
