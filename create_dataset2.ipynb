# %% [markdown]
# ### now as we know the dataset must be compatible to insert into a neural network
# ### so we need to convert it into .csv file

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from os import listdir
from os.path import isfile, join

# %% [markdown]
# ### first, we defined a function to extract out log-mel-spectrograms of each clip

# %%
#define a function to get log-melspectrograms of audio files
def log_mel_spec(file):
    y,sr = librosa.load(file)
    
    five_sec = 5 * sr
    diff = abs(len(y) - five_sec)
    #if len >5 sec then slice wave
    if(len(y) > five_sec):
        st_slice = np.random.randint(diff)
        end_slice = len(y) - (diff - st_slice)
        y = y[st_slice:end_slice]
        
    #if len<5 sec then pad wave
    elif(len(y) < five_sec):
        st_pad = np.random.randint(diff)
        end_pad = diff - st_pad
        y = np.pad(y, (st_pad,end_pad), "constant")

    mel = librosa.feature.melspectrogram(y = y)
    #log_mel = librosa.amplitude_to_db(mel)
    log_mel = librosa.power_to_db(mel)
    return log_mel

# %% [markdown]
# ### now we extract filenames from good category

# %%
#extract list of filenames from 'good' folder
dir_good = "H:/original+augmented2/good"
good_files = [f for f in listdir(dir_good) if isfile(join(dir_good, f))]

# %%
good_files
# Out:
# ['flip-rahul-brian-clip1_3,3,3.wav',
#  'flip-rahul-brian-clip3_3,3,2.5.wav',
#  'flip-rahul-brian-clip5_3,3,3.wav',
#  'flip-rahul-clip108_3,3,2.5.wav',
#  'flip-rahul-clip114_3,2.5,3.wav',
#  'flip-rahul-clip176_3,2.5,3.wav',
#  'flip-rahul-clip196_3,3,2.5.wav',
#  'flip-rahul-clip197_3,3,3.wav',
#  'flip-rahul-clip198_3,3,3.wav',
#  'flip-rahul-clip199_3,3,3.wav',
#  'flip-rahul-clip201_3,3,3.wav',
#  'flip-rahul-clip202_3,3,3.wav',
#  'flip-rahul-clip203_3,3,3.wav',
#  'flip-rahul-clip204_3,3,3.wav',
#  'flip-rahul-clip205_3,3,3.wav',
#  'flip-rahul-clip206_3,3,3.wav',
#  'flip-rahul-clip220_3,2.5,3.wav',
#  'flip-rahul-clip227_3,2.5,3.wav',
#  'flip-rahul-clip250_3,3,2.5.wav',
#  'flip-rahul-clip251_3,3,2.5.wav',
#  'flip-rahul-clip252_3,3,2.5.wav',
#  'flip-rahul-clip254_3,2.5,3.wav',
#  'flip-rahul-clip27_3,3,3.wav',
#  'flip-rahul-clip281_3,3,2.5.wav',
#  'flip-rahul-clip291_3,3,2.5.wav',
#  'flip-rahul-clip302_3,3,2.5.wav',
#  'flip-rahul-clip329_3,3,3.wav',
#  'flip-rahul-clip330_3,3,3.wav',
#  'flip-rahul-clip331_3,3,2.5.wav',
#  'flip-rahul-clip332_3,3,2.5.wav',
#  'flip-rahul-clip333_3,3,2.5.wav',
#  'flip-rahul-clip334_3,3,3.wav',
#  'flip-rahul-clip335_3,3,3.wav',
#  'flip-rahul-clip342_3,3,2.5.wav',
#  'flip-rahul-clip353_2.5,3,3.wav',
#  'flip-rahul-clip355_3,3,3.wav',
#  'flip-rahul-clip361_3,2.5,3.wav',
#  'flip-rahul-clip395_3,3,2.5.wav',
#  'flip-rahul-clip397_2.5,3,3.wav',
#  'flip-rahul-clip398_3,3,3.wav',
#  'flip-rahul-clip401_3,2.5,3.wav',
#  'flip-rahul-clip416_2.5,3,3.wav',
#  'flip-rahul-clip448_3,3,2.5.wav',
#  'flip-rahul-clip456_3,3,2.5.wav',
#  'flip-rahul-clip458_3,3,2.5.wav',
#  'flip-rahul-clip45_3,3,3.wav',
#  'flip-rahul-clip46_3,3,2.5.wav',
#  'flip-rahul-clip470_3,3,2.5.wav',
#  'flip-rahul-clip47_3,3,2.5.wav',
#  'flip-rahul-clip495_3,3,2.5.wav',
#  'flip-rahul-clip498_3,2.5,3.wav',
#  'flip-rahul-clip511_3,2.5,3.wav',
#  'flip-rahul-clip553_2.5,3,3.wav',
#  'flip-rahul-clip556_3,3,2.5.wav',
#  'flip-rahul-clip560_3,3,2.5.wav',
#  'flip-rahul-clip572_3,3,3.wav',
#  'flip-rahul-clip591_3,3,3.wav',
#  'flip-rahul-clip593_3,3,3.wav',
#  'flip-rahul-clip595_3,2.5,3.wav',
#  'flip-rahul-clip596_3,3,2.5.wav',
#  'flip-rahul-clip597_3,3,3.wav',
#  'flip-rahul-clip598_3,2.5,3.wav',
#  'flip-rahul-clip599_3,3,3.wav',
#  'flip-rahul-clip5_3,3,3.wav',
#  'flip-rahul-clip600_3,3,3.wav',
#  'flip-rahul-clip601_3,3,3.wav',
#  'flip-rahul-clip603_3,3,3.wav',
#  'flip-rahul-clip66_3,2.5,3.wav',
#  'flip-rahul-clip67_3,3,2.5.wav',
#  'flip-rahul-clip68_3,3,3.wav',
#  'flip-rahul-clip72_3,3,3.wav',
#  'flip-rahul-clip7_3,3,3.wav',
#  'flip-rahul-clip84_3,3,3.wav',
#  'flip-rahul-clip85_3,3,3.wav',
#  'flip-rahul-clip88_3,3,2.5.wav',
#  'flip-rahul-gang-clip1_3,3,2.5.wav',
#  'flip-rahul-gang-clip2_3,3,3.wav',
#  'flip-rahul-gang-clip4_3,3,2.5.wav',
#  'flip-rahul-gang-clip5_3,3,3.wav',
#  'flip-rahul-habits-clip4_3,2.5,3.wav',
#  'flip-rahul-habits-clip5_3,3,3.wav',
#  'flip-rahul-habits-clip6_3,3,3.wav',
#  'flip-rahul-humor-clip3_3,3,3.wav',
#  'flip-rahul-questions-clip1_3,3,3.wav',
#  'flip-rahul-questions-clip3_3,3,2.8.wav',
#  'flip-rahul-questions-clip7_2.5,3,3.wav',
#  'flip-ravina-set1-clip28_3,2.5,3.wav',
#  'flip-ravina-set1-clip42_3,2.5,3.wav',
#  'flip-ravina-set1-clip47_3,3,2.5.wav',
#  'flip-ravina-set2-clip30_3,3,3.wav',
#  'flip-ravina-set2-clip41_2.5,3,3.wav',
#  'flip-ravina-set3-clip10_2.5,3,3.wav',
#  'flip-ravina-set3-clip25_3,3,2.5.wav',
#  'flip-ravina-set3-clip28_3,3,3.wav',
#  'flip-ravina-set3-clip29_3,3,3.wav',
#  'flip-ravina-set3-clip31_2.5,3,3.wav',
#  'flip-ravina-set3-clip33_3,3,3.wav',
#  'flip-ravina-set3-clip36_3,3,3.wav',
#  'flip-ravina-set3-clip37_3,3,2.5.wav',
#  'flip-ravina-set3-clip46_3,3,2.5.wav',
#  'flip-ravina-set3-clip47_3,3,2.5.wav',
#  'flip-ravina-set4-clip26_2.5,3,3.wav',
#  'flip-ravina-set4-clip28_3,2.5,3.wav',
#  'flip-ravina-set4-clip29_2.5,3,3.wav',
#  'flip-ravina-set4-clip33_2.5,3,3.wav',
#  'flip-ravina-set4-clip61_3,2.5,3.wav',
#  'flip-ravina-set4-clip62_2.5,3,3.wav',
#  'flip-ravina-set4-clip63_3,3,3.wav',
#  'flip-ravina-set4-clip66_2.5,3,3.wav',
#  'flip-ravina-set4-clip67_3,3,3.wav',
#  'flip-ravina-set4-clip70_3,3,3.wav',
#  'flip-ravina-set4-clip72_3,3,2.5.wav',
#  'flip-ravina-set4-clip86_2.5,3,3.wav',
#  'flip-saijal-set1-clip22_3,2.5,3.wav',
#  'flip-saijal-set1-clip23_3,3,2.5.wav',
#  'flip-saijal-set1-clip24_3,3,2.5.wav',
#  'flip-saijal-set1-clip26_3,3,2.5.wav',
#  'flip-saijal-set1-clip27_3,3,3.wav',
#  'flip-saijal-set1-clip30_3,2.5,3.wav',
#  'flip-saijal-set1-clip31_3,2.5,3.wav',
#  'flip-saijal-set1-clip33_3,2.5,3.wav',
#  'flip-saijal-set1-clip36_3,3,3.wav',
#  'flip-saijal-set1-clip40_3,2.5,3.wav',
#  'flip-saijal-set1-clip51_3,2.5,3.wav',
#  'flip-saijal-set1-clip7_2.5,3,3.wav',
#  'flip-saijal-set1-clip8_2.5,3,3.wav',
#  'flip-saijal-set2-clip10_2.5,3,3.wav',
#  'flip-saijal-set2-clip40_3,3,3.wav',
#  'flip-saijal-set2-clip44_2.5,3,3.wav',
#  'flip-saijal-set3-clip10_3,3,3.wav',
#  'flip-saijal-set3-clip13_3,3,3.wav',
#  'flip-saijal-set3-clip14_3,3,2.5.wav',
#  'flip-saijal-set3-clip15_3,3,2.5.wav',
#  'flip-saijal-set3-clip17_3,3,2.5.wav',
#  'flip-saijal-set3-clip18_3,3,3.wav',
#  'flip-saijal-set3-clip2_2.5,3,3.wav',
#  'flip-saijal-set3-clip34_3,3,2.5.wav',
#  'flip-saijal-set3-clip4_3,3,2.5.wav',
#  'flip-saijal-set3-clip50_2.5,3,3.wav',
#  'flip-saijal-set3-clip5_3,2.5,3.wav',
#  'flip-saijal-set3-clip6_3,3,3.wav',
#  'flip-saijal-set3-clip7_3,2.5,3.wav',
#  'flip-saijal-set3-clip9_3,3,3.wav',
#  'flip-saijal-set4-clip23_3,3,3.wav',
#  'flip-saijal-set4-clip24_3,3,3.wav',
#  'flip-saijal-set4-clip25_3,3,3.wav',
#  'flip-saijal-set4-clip26_3,3,3.wav',
#  'flip-saijal-set4-clip30_3,3,3.wav',
#  'flip-saijal-set4-clip31_3,3,2.5.wav',
#  'flip-saijal-set5-clip24_3,3,2.5.wav',
#  'flip-saijal-set5-clip37_3,3,2.5.wav',
#  'flip-saijal-set5-clip7_3,3,2.5.wav',
#  'flip-saijal-set6-clip33_3,3,2.5.wav',
#  'flip-saijal-set6-clip34_2.5,3,3.wav',
#  'flip-saijal-set6-clip35_3,3,3.wav',
#  'flip-saijal-set6-clip38_3,3,3.wav',
#  'flip-saijal-set6-clip39_3,3,3.wav',
#  'rahul-brian-clip1_3,3,3.wav',
#  'rahul-brian-clip3_3,3,2.5.wav',
#  'rahul-brian-clip5_3,3,3.wav',
#  'rahul-clip108_3,3,2.5.wav',
#  'rahul-clip114_3,2.5,3.wav',
#  'rahul-clip176_3,2.5,3.wav',
#  'rahul-clip196_3,3,2.5.wav',
#  'rahul-clip197_3,3,3.wav',
#  'rahul-clip198_3,3,3.wav',
#  'rahul-clip199_3,3,3.wav',
#  'rahul-clip201_3,3,3.wav',
#  'rahul-clip202_3,3,3.wav',
#  'rahul-clip203_3,3,3.wav',
#  'rahul-clip204_3,3,3.wav',
#  'rahul-clip205_3,3,3.wav',
#  'rahul-clip206_3,3,3.wav',
#  'rahul-clip220_3,2.5,3.wav',
#  'rahul-clip227_3,2.5,3.wav',
#  'rahul-clip250_3,3,2.5.wav',
#  'rahul-clip251_3,3,2.5.wav',
#  'rahul-clip252_3,3,2.5.wav',
#  'rahul-clip254_3,2.5,3.wav',
#  'rahul-clip27_3,3,3.wav',
#  'rahul-clip281_3,3,2.5.wav',
#  'rahul-clip291_3,3,2.5.wav',
#  'rahul-clip302_3,3,2.5.wav',
#  'rahul-clip329_3,3,3.wav',
#  'rahul-clip330_3,3,3.wav',
#  'rahul-clip331_3,3,2.5.wav',
#  'rahul-clip332_3,3,2.5.wav',
#  'rahul-clip333_3,3,2.5.wav',
#  'rahul-clip334_3,3,3.wav',
#  'rahul-clip335_3,3,3.wav',
#  'rahul-clip342_3,3,2.5.wav',
#  'rahul-clip353_2.5,3,3.wav',
#  'rahul-clip355_3,3,3.wav',
#  'rahul-clip361_3,2.5,3.wav',
#  'rahul-clip395_3,3,2.5.wav',
#  'rahul-clip397_2.5,3,3.wav',
#  'rahul-clip398_3,3,3.wav',
#  'rahul-clip401_3,2.5,3.wav',
#  'rahul-clip416_2.5,3,3.wav',
#  'rahul-clip448_3,3,2.5.wav',
#  'rahul-clip456_3,3,2.5.wav',
#  'rahul-clip458_3,3,2.5.wav',
#  'rahul-clip45_3,3,3.wav',
#  'rahul-clip46_3,3,2.5.wav',
#  'rahul-clip470_3,3,2.5.wav',
#  'rahul-clip47_3,3,2.5.wav',
#  'rahul-clip495_3,3,2.5.wav',
#  'rahul-clip498_3,2.5,3.wav',
#  'rahul-clip511_3,2.5,3.wav',
#  'rahul-clip553_2.5,3,3.wav',
#  'rahul-clip556_3,3,2.5.wav',
#  'rahul-clip560_3,3,2.5.wav',
#  'rahul-clip572_3,3,3.wav',
#  'rahul-clip591_3,3,3.wav',
#  'rahul-clip593_3,3,3.wav',
#  'rahul-clip595_3,2.5,3.wav',
#  'rahul-clip596_3,3,2.5.wav',
#  'rahul-clip597_3,3,3.wav',
#  'rahul-clip598_3,2.5,3.wav',
#  'rahul-clip599_3,3,3.wav',
#  'rahul-clip5_3,3,3.wav',
#  'rahul-clip600_3,3,3.wav',
#  'rahul-clip601_3,3,3.wav',
#  'rahul-clip603_3,3,3.wav',
#  'rahul-clip66_3,2.5,3.wav',
#  'rahul-clip67_3,3,2.5.wav',
#  'rahul-clip68_3,3,3.wav',
#  'rahul-clip72_3,3,3.wav',
#  'rahul-clip7_3,3,3.wav',
#  'rahul-clip84_3,3,3.wav',
#  'rahul-clip85_3,3,3.wav',
#  'rahul-clip88_3,3,2.5.wav',
#  'rahul-gang-clip1_3,3,2.5.wav',
#  'rahul-gang-clip2_3,3,3.wav',
#  'rahul-gang-clip4_3,3,2.5.wav',
#  'rahul-gang-clip5_3,3,3.wav',
#  'rahul-habits-clip4_3,2.5,3.wav',
#  'rahul-habits-clip5_3,3,3.wav',
#  'rahul-habits-clip6_3,3,3.wav',
#  'rahul-humor-clip3_3,3,3.wav',
#  'rahul-questions-clip1_3,3,3.wav',
#  'rahul-questions-clip3_3,3,2.8.wav',
#  'rahul-questions-clip7_2.5,3,3.wav',
#  'ravina-set1-clip28_3,2.5,3.wav',
#  'ravina-set1-clip42_3,2.5,3.wav',
#  'ravina-set1-clip47_3,3,2.5.wav',
#  'ravina-set2-clip30_3,3,3.wav',
#  'ravina-set2-clip41_2.5,3,3.wav',
#  'ravina-set3-clip10_2.5,3,3.wav',
#  'ravina-set3-clip25_3,3,2.5.wav',
#  'ravina-set3-clip28_3,3,3.wav',
#  'ravina-set3-clip29_3,3,3.wav',
#  'ravina-set3-clip31_2.5,3,3.wav',
#  'ravina-set3-clip33_3,3,3.wav',
#  'ravina-set3-clip36_3,3,3.wav',
#  'ravina-set3-clip37_3,3,2.5.wav',
#  'ravina-set3-clip46_3,3,2.5.wav',
#  'ravina-set3-clip47_3,3,2.5.wav',
#  'ravina-set4-clip26_2.5,3,3.wav',
#  'ravina-set4-clip28_3,2.5,3.wav',
#  'ravina-set4-clip29_2.5,3,3.wav',
#  'ravina-set4-clip33_2.5,3,3.wav',
#  'ravina-set4-clip61_3,2.5,3.wav',
#  'ravina-set4-clip62_2.5,3,3.wav',
#  'ravina-set4-clip63_3,3,3.wav',
#  'ravina-set4-clip66_2.5,3,3.wav',
#  'ravina-set4-clip67_3,3,3.wav',
#  'ravina-set4-clip70_3,3,3.wav',
#  'ravina-set4-clip72_3,3,2.5.wav',
#  'ravina-set4-clip86_2.5,3,3.wav',
#  'saijal-set1-clip22_3,2.5,3.wav',
#  'saijal-set1-clip23_3,3,2.5.wav',
#  'saijal-set1-clip24_3,3,2.5.wav',
#  'saijal-set1-clip26_3,3,2.5.wav',
#  'saijal-set1-clip27_3,3,3.wav',
#  'saijal-set1-clip30_3,2.5,3.wav',
#  'saijal-set1-clip31_3,2.5,3.wav',
#  'saijal-set1-clip33_3,2.5,3.wav',
#  'saijal-set1-clip36_3,3,3.wav',
#  'saijal-set1-clip40_3,2.5,3.wav',
#  'saijal-set1-clip51_3,2.5,3.wav',
#  'saijal-set1-clip7_2.5,3,3.wav',
#  'saijal-set1-clip8_2.5,3,3.wav',
#  'saijal-set2-clip10_2.5,3,3.wav',
#  'saijal-set2-clip40_3,3,3.wav',
#  'saijal-set2-clip44_2.5,3,3.wav',
#  'saijal-set3-clip10_3,3,3.wav',
#  'saijal-set3-clip13_3,3,3.wav',
#  'saijal-set3-clip14_3,3,2.5.wav',
#  'saijal-set3-clip15_3,3,2.5.wav',
#  'saijal-set3-clip17_3,3,2.5.wav',
#  'saijal-set3-clip18_3,3,3.wav',
#  'saijal-set3-clip2_2.5,3,3.wav',
#  'saijal-set3-clip34_3,3,2.5.wav',
#  'saijal-set3-clip4_3,3,2.5.wav',
#  'saijal-set3-clip50_2.5,3,3.wav',
#  'saijal-set3-clip5_3,2.5,3.wav',
#  'saijal-set3-clip6_3,3,3.wav',
#  'saijal-set3-clip7_3,2.5,3.wav',
#  'saijal-set3-clip9_3,3,3.wav',
#  'saijal-set4-clip23_3,3,3.wav',
#  'saijal-set4-clip24_3,3,3.wav',
#  'saijal-set4-clip25_3,3,3.wav',
#  'saijal-set4-clip26_3,3,3.wav',
#  'saijal-set4-clip30_3,3,3.wav',
#  'saijal-set4-clip31_3,3,2.5.wav',
#  'saijal-set5-clip24_3,3,2.5.wav',
#  'saijal-set5-clip37_3,3,2.5.wav',
#  'saijal-set5-clip7_3,3,2.5.wav',
#  'saijal-set6-clip33_3,3,2.5.wav',
#  'saijal-set6-clip34_2.5,3,3.wav',
#  'saijal-set6-clip35_3,3,3.wav',
#  'saijal-set6-clip38_3,3,3.wav',
#  'saijal-set6-clip39_3,3,3.wav',
#  'shift0-rahul-brian-clip1_3,3,3.wav',
#  'shift0-rahul-brian-clip3_3,3,2.5.wav',
#  'shift0-rahul-brian-clip5_3,3,3.wav',
#  'shift0-rahul-clip108_3,3,2.5.wav',
#  'shift0-rahul-clip114_3,2.5,3.wav',
#  'shift0-rahul-clip176_3,2.5,3.wav',
#  'shift0-rahul-clip196_3,3,2.5.wav',
#  'shift0-rahul-clip197_3,3,3.wav',
#  'shift0-rahul-clip198_3,3,3.wav',
#  'shift0-rahul-clip199_3,3,3.wav',
#  'shift0-rahul-clip201_3,3,3.wav',
#  'shift0-rahul-clip202_3,3,3.wav',
#  'shift0-rahul-clip203_3,3,3.wav',
#  'shift0-rahul-clip204_3,3,3.wav',
#  'shift0-rahul-clip205_3,3,3.wav',
#  'shift0-rahul-clip206_3,3,3.wav',
#  'shift0-rahul-clip220_3,2.5,3.wav',
#  'shift0-rahul-clip227_3,2.5,3.wav',
#  'shift0-rahul-clip250_3,3,2.5.wav',
#  'shift0-rahul-clip251_3,3,2.5.wav',
#  'shift0-rahul-clip252_3,3,2.5.wav',
#  'shift0-rahul-clip254_3,2.5,3.wav',
#  'shift0-rahul-clip27_3,3,3.wav',
#  'shift0-rahul-clip281_3,3,2.5.wav',
#  'shift0-rahul-clip291_3,3,2.5.wav',
#  'shift0-rahul-clip302_3,3,2.5.wav',
#  'shift0-rahul-clip329_3,3,3.wav',
#  'shift0-rahul-clip330_3,3,3.wav',
#  'shift0-rahul-clip331_3,3,2.5.wav',
#  'shift0-rahul-clip332_3,3,2.5.wav',
#  'shift0-rahul-clip333_3,3,2.5.wav',
#  'shift0-rahul-clip334_3,3,3.wav',
#  'shift0-rahul-clip335_3,3,3.wav',
#  'shift0-rahul-clip342_3,3,2.5.wav',
#  'shift0-rahul-clip353_2.5,3,3.wav',
#  'shift0-rahul-clip355_3,3,3.wav',
#  'shift0-rahul-clip361_3,2.5,3.wav',
#  'shift0-rahul-clip395_3,3,2.5.wav',
#  'shift0-rahul-clip397_2.5,3,3.wav',
#  'shift0-rahul-clip398_3,3,3.wav',
#  'shift0-rahul-clip401_3,2.5,3.wav',
#  'shift0-rahul-clip416_2.5,3,3.wav',
#  'shift0-rahul-clip448_3,3,2.5.wav',
#  'shift0-rahul-clip456_3,3,2.5.wav',
#  'shift0-rahul-clip458_3,3,2.5.wav',
#  'shift0-rahul-clip45_3,3,3.wav',
#  'shift0-rahul-clip46_3,3,2.5.wav',
#  'shift0-rahul-clip470_3,3,2.5.wav',
#  'shift0-rahul-clip47_3,3,2.5.wav',
#  'shift0-rahul-clip495_3,3,2.5.wav',
#  'shift0-rahul-clip498_3,2.5,3.wav',
#  'shift0-rahul-clip511_3,2.5,3.wav',
#  'shift0-rahul-clip553_2.5,3,3.wav',
#  'shift0-rahul-clip556_3,3,2.5.wav',
#  'shift0-rahul-clip560_3,3,2.5.wav',
#  'shift0-rahul-clip572_3,3,3.wav',
#  'shift0-rahul-clip591_3,3,3.wav',
#  'shift0-rahul-clip593_3,3,3.wav',
#  'shift0-rahul-clip595_3,2.5,3.wav',
#  'shift0-rahul-clip596_3,3,2.5.wav',
#  'shift0-rahul-clip597_3,3,3.wav',
#  'shift0-rahul-clip598_3,2.5,3.wav',
#  'shift0-rahul-clip599_3,3,3.wav',
#  'shift0-rahul-clip5_3,3,3.wav',
#  'shift0-rahul-clip600_3,3,3.wav',
#  'shift0-rahul-clip601_3,3,3.wav',
#  'shift0-rahul-clip603_3,3,3.wav',
#  'shift0-rahul-clip66_3,2.5,3.wav',
#  'shift0-rahul-clip67_3,3,2.5.wav',
#  'shift0-rahul-clip68_3,3,3.wav',
#  'shift0-rahul-clip72_3,3,3.wav',
#  'shift0-rahul-clip7_3,3,3.wav',
#  'shift0-rahul-clip84_3,3,3.wav',
#  'shift0-rahul-clip85_3,3,3.wav',
#  'shift0-rahul-clip88_3,3,2.5.wav',
#  'shift0-rahul-gang-clip1_3,3,2.5.wav',
#  'shift0-rahul-gang-clip2_3,3,3.wav',
#  'shift0-rahul-gang-clip4_3,3,2.5.wav',
#  'shift0-rahul-gang-clip5_3,3,3.wav',
#  'shift0-rahul-habits-clip4_3,2.5,3.wav',
#  'shift0-rahul-habits-clip5_3,3,3.wav',
#  'shift0-rahul-habits-clip6_3,3,3.wav',
#  'shift0-rahul-humor-clip3_3,3,3.wav',
#  'shift0-rahul-questions-clip1_3,3,3.wav',
#  'shift0-rahul-questions-clip3_3,3,2.8.wav',
#  'shift0-rahul-questions-clip7_2.5,3,3.wav',
#  'shift0-ravina-set1-clip28_3,2.5,3.wav',
#  'shift0-ravina-set1-clip42_3,2.5,3.wav',
#  'shift0-ravina-set1-clip47_3,3,2.5.wav',
#  'shift0-ravina-set2-clip30_3,3,3.wav',
#  'shift0-ravina-set2-clip41_2.5,3,3.wav',
#  'shift0-ravina-set3-clip10_2.5,3,3.wav',
#  'shift0-ravina-set3-clip25_3,3,2.5.wav',
#  'shift0-ravina-set3-clip28_3,3,3.wav',
#  'shift0-ravina-set3-clip29_3,3,3.wav',
#  'shift0-ravina-set3-clip31_2.5,3,3.wav',
#  'shift0-ravina-set3-clip33_3,3,3.wav',
#  'shift0-ravina-set3-clip36_3,3,3.wav',
#  'shift0-ravina-set3-clip37_3,3,2.5.wav',
#  'shift0-ravina-set3-clip46_3,3,2.5.wav',
#  'shift0-ravina-set3-clip47_3,3,2.5.wav',
#  'shift0-ravina-set4-clip26_2.5,3,3.wav',
#  'shift0-ravina-set4-clip28_3,2.5,3.wav',
#  'shift0-ravina-set4-clip29_2.5,3,3.wav',
#  'shift0-ravina-set4-clip33_2.5,3,3.wav',
#  'shift0-ravina-set4-clip61_3,2.5,3.wav',
#  'shift0-ravina-set4-clip62_2.5,3,3.wav',
#  'shift0-ravina-set4-clip63_3,3,3.wav',
#  'shift0-ravina-set4-clip66_2.5,3,3.wav',
#  'shift0-ravina-set4-clip67_3,3,3.wav',
#  'shift0-ravina-set4-clip70_3,3,3.wav',
#  'shift0-ravina-set4-clip72_3,3,2.5.wav',
#  'shift0-ravina-set4-clip86_2.5,3,3.wav',
#  'shift0-saijal-set1-clip22_3,2.5,3.wav',
#  'shift0-saijal-set1-clip23_3,3,2.5.wav',
#  'shift0-saijal-set1-clip24_3,3,2.5.wav',
#  'shift0-saijal-set1-clip26_3,3,2.5.wav',
#  'shift0-saijal-set1-clip27_3,3,3.wav',
#  'shift0-saijal-set1-clip30_3,2.5,3.wav',
#  'shift0-saijal-set1-clip31_3,2.5,3.wav',
#  'shift0-saijal-set1-clip33_3,2.5,3.wav',
#  'shift0-saijal-set1-clip36_3,3,3.wav',
#  'shift0-saijal-set1-clip40_3,2.5,3.wav',
#  'shift0-saijal-set1-clip51_3,2.5,3.wav',
#  'shift0-saijal-set1-clip7_2.5,3,3.wav',
#  'shift0-saijal-set1-clip8_2.5,3,3.wav',
#  'shift0-saijal-set2-clip10_2.5,3,3.wav',
#  'shift0-saijal-set2-clip40_3,3,3.wav',
#  'shift0-saijal-set2-clip44_2.5,3,3.wav',
#  'shift0-saijal-set3-clip10_3,3,3.wav',
#  'shift0-saijal-set3-clip13_3,3,3.wav',
#  'shift0-saijal-set3-clip14_3,3,2.5.wav',
#  'shift0-saijal-set3-clip15_3,3,2.5.wav',
#  'shift0-saijal-set3-clip17_3,3,2.5.wav',
#  'shift0-saijal-set3-clip18_3,3,3.wav',
#  'shift0-saijal-set3-clip2_2.5,3,3.wav',
#  'shift0-saijal-set3-clip34_3,3,2.5.wav',
#  'shift0-saijal-set3-clip4_3,3,2.5.wav',
#  'shift0-saijal-set3-clip50_2.5,3,3.wav',
#  'shift0-saijal-set3-clip5_3,2.5,3.wav',
#  'shift0-saijal-set3-clip6_3,3,3.wav',
#  'shift0-saijal-set3-clip7_3,2.5,3.wav',
#  'shift0-saijal-set3-clip9_3,3,3.wav',
#  'shift0-saijal-set4-clip23_3,3,3.wav',
#  'shift0-saijal-set4-clip24_3,3,3.wav',
#  'shift0-saijal-set4-clip25_3,3,3.wav',
#  'shift0-saijal-set4-clip26_3,3,3.wav',
#  'shift0-saijal-set4-clip30_3,3,3.wav',
#  'shift0-saijal-set4-clip31_3,3,2.5.wav',
#  'shift0-saijal-set5-clip24_3,3,2.5.wav',
#  'shift0-saijal-set5-clip37_3,3,2.5.wav',
#  'shift0-saijal-set5-clip7_3,3,2.5.wav',
#  'shift0-saijal-set6-clip33_3,3,2.5.wav',
#  'shift0-saijal-set6-clip34_2.5,3,3.wav',
#  'shift0-saijal-set6-clip35_3,3,3.wav',
#  'shift0-saijal-set6-clip38_3,3,3.wav',
#  'shift0-saijal-set6-clip39_3,3,3.wav',
#  'shift0_flip-rahul-brian-clip1_3,3,3.wav',
#  'shift0_flip-rahul-brian-clip3_3,3,2.5.wav',
#  'shift0_flip-rahul-brian-clip5_3,3,3.wav',
#  'shift0_flip-rahul-clip108_3,3,2.5.wav',
#  'shift0_flip-rahul-clip114_3,2.5,3.wav',
#  'shift0_flip-rahul-clip176_3,2.5,3.wav',
#  'shift0_flip-rahul-clip196_3,3,2.5.wav',
#  'shift0_flip-rahul-clip197_3,3,3.wav',
#  'shift0_flip-rahul-clip198_3,3,3.wav',
#  'shift0_flip-rahul-clip199_3,3,3.wav',
#  'shift0_flip-rahul-clip201_3,3,3.wav',
#  'shift0_flip-rahul-clip202_3,3,3.wav',
#  'shift0_flip-rahul-clip203_3,3,3.wav',
#  'shift0_flip-rahul-clip204_3,3,3.wav',
#  'shift0_flip-rahul-clip205_3,3,3.wav',
#  'shift0_flip-rahul-clip206_3,3,3.wav',
#  'shift0_flip-rahul-clip220_3,2.5,3.wav',
#  'shift0_flip-rahul-clip227_3,2.5,3.wav',
#  'shift0_flip-rahul-clip250_3,3,2.5.wav',
#  'shift0_flip-rahul-clip251_3,3,2.5.wav',
#  'shift0_flip-rahul-clip252_3,3,2.5.wav',
#  'shift0_flip-rahul-clip254_3,2.5,3.wav',
#  'shift0_flip-rahul-clip27_3,3,3.wav',
#  'shift0_flip-rahul-clip281_3,3,2.5.wav',
#  'shift0_flip-rahul-clip291_3,3,2.5.wav',
#  'shift0_flip-rahul-clip302_3,3,2.5.wav',
#  'shift0_flip-rahul-clip329_3,3,3.wav',
#  'shift0_flip-rahul-clip330_3,3,3.wav',
#  'shift0_flip-rahul-clip331_3,3,2.5.wav',
#  'shift0_flip-rahul-clip332_3,3,2.5.wav',
#  'shift0_flip-rahul-clip333_3,3,2.5.wav',
#  'shift0_flip-rahul-clip334_3,3,3.wav',
#  'shift0_flip-rahul-clip335_3,3,3.wav',
#  'shift0_flip-rahul-clip342_3,3,2.5.wav',
#  'shift0_flip-rahul-clip353_2.5,3,3.wav',
#  'shift0_flip-rahul-clip355_3,3,3.wav',
#  'shift0_flip-rahul-clip361_3,2.5,3.wav',
#  'shift0_flip-rahul-clip395_3,3,2.5.wav',
#  'shift0_flip-rahul-clip397_2.5,3,3.wav',
#  'shift0_flip-rahul-clip398_3,3,3.wav',
#  'shift0_flip-rahul-clip401_3,2.5,3.wav',
#  'shift0_flip-rahul-clip416_2.5,3,3.wav',
#  'shift0_flip-rahul-clip448_3,3,2.5.wav',
#  'shift0_flip-rahul-clip456_3,3,2.5.wav',
#  'shift0_flip-rahul-clip458_3,3,2.5.wav',
#  'shift0_flip-rahul-clip45_3,3,3.wav',
#  'shift0_flip-rahul-clip46_3,3,2.5.wav',
#  'shift0_flip-rahul-clip470_3,3,2.5.wav',
#  'shift0_flip-rahul-clip47_3,3,2.5.wav',
#  'shift0_flip-rahul-clip495_3,3,2.5.wav',
#  'shift0_flip-rahul-clip498_3,2.5,3.wav',
#  'shift0_flip-rahul-clip511_3,2.5,3.wav',
#  'shift0_flip-rahul-clip553_2.5,3,3.wav',
#  'shift0_flip-rahul-clip556_3,3,2.5.wav',
#  'shift0_flip-rahul-clip560_3,3,2.5.wav',
#  'shift0_flip-rahul-clip572_3,3,3.wav',
#  'shift0_flip-rahul-clip591_3,3,3.wav',
#  'shift0_flip-rahul-clip593_3,3,3.wav',
#  'shift0_flip-rahul-clip595_3,2.5,3.wav',
#  'shift0_flip-rahul-clip596_3,3,2.5.wav',
#  'shift0_flip-rahul-clip597_3,3,3.wav',
#  'shift0_flip-rahul-clip598_3,2.5,3.wav',
#  'shift0_flip-rahul-clip599_3,3,3.wav',
#  'shift0_flip-rahul-clip5_3,3,3.wav',
#  'shift0_flip-rahul-clip600_3,3,3.wav',
#  'shift0_flip-rahul-clip601_3,3,3.wav',
#  'shift0_flip-rahul-clip603_3,3,3.wav',
#  'shift0_flip-rahul-clip66_3,2.5,3.wav',
#  'shift0_flip-rahul-clip67_3,3,2.5.wav',
#  'shift0_flip-rahul-clip68_3,3,3.wav',
#  'shift0_flip-rahul-clip72_3,3,3.wav',
#  'shift0_flip-rahul-clip7_3,3,3.wav',
#  'shift0_flip-rahul-clip84_3,3,3.wav',
#  'shift0_flip-rahul-clip85_3,3,3.wav',
#  'shift0_flip-rahul-clip88_3,3,2.5.wav',
#  'shift0_flip-rahul-gang-clip1_3,3,2.5.wav',
#  'shift0_flip-rahul-gang-clip2_3,3,3.wav',
#  'shift0_flip-rahul-gang-clip4_3,3,2.5.wav',
#  'shift0_flip-rahul-gang-clip5_3,3,3.wav',
#  'shift0_flip-rahul-habits-clip4_3,2.5,3.wav',
#  'shift0_flip-rahul-habits-clip5_3,3,3.wav',
#  'shift0_flip-rahul-habits-clip6_3,3,3.wav',
#  'shift0_flip-rahul-humor-clip3_3,3,3.wav',
#  'shift0_flip-rahul-questions-clip1_3,3,3.wav',
#  'shift0_flip-rahul-questions-clip3_3,3,2.8.wav',
#  'shift0_flip-rahul-questions-clip7_2.5,3,3.wav',
#  'shift0_flip-ravina-set1-clip28_3,2.5,3.wav',
#  'shift0_flip-ravina-set1-clip42_3,2.5,3.wav',
#  'shift0_flip-ravina-set1-clip47_3,3,2.5.wav',
#  'shift0_flip-ravina-set2-clip30_3,3,3.wav',
#  'shift0_flip-ravina-set2-clip41_2.5,3,3.wav',
#  'shift0_flip-ravina-set3-clip10_2.5,3,3.wav',
#  'shift0_flip-ravina-set3-clip25_3,3,2.5.wav',
#  'shift0_flip-ravina-set3-clip28_3,3,3.wav',
#  'shift0_flip-ravina-set3-clip29_3,3,3.wav',
#  'shift0_flip-ravina-set3-clip31_2.5,3,3.wav',
#  'shift0_flip-ravina-set3-clip33_3,3,3.wav',
#  'shift0_flip-ravina-set3-clip36_3,3,3.wav',
#  'shift0_flip-ravina-set3-clip37_3,3,2.5.wav',
#  'shift0_flip-ravina-set3-clip46_3,3,2.5.wav',
#  'shift0_flip-ravina-set3-clip47_3,3,2.5.wav',
#  'shift0_flip-ravina-set4-clip26_2.5,3,3.wav',
#  'shift0_flip-ravina-set4-clip28_3,2.5,3.wav',
#  'shift0_flip-ravina-set4-clip29_2.5,3,3.wav',
#  'shift0_flip-ravina-set4-clip33_2.5,3,3.wav',
#  'shift0_flip-ravina-set4-clip61_3,2.5,3.wav',
#  'shift0_flip-ravina-set4-clip62_2.5,3,3.wav',
#  'shift0_flip-ravina-set4-clip63_3,3,3.wav',
#  'shift0_flip-ravina-set4-clip66_2.5,3,3.wav',
#  'shift0_flip-ravina-set4-clip67_3,3,3.wav',
#  'shift0_flip-ravina-set4-clip70_3,3,3.wav',
#  'shift0_flip-ravina-set4-clip72_3,3,2.5.wav',
#  'shift0_flip-ravina-set4-clip86_2.5,3,3.wav',
#  'shift0_flip-saijal-set1-clip22_3,2.5,3.wav',
#  'shift0_flip-saijal-set1-clip23_3,3,2.5.wav',
#  'shift0_flip-saijal-set1-clip24_3,3,2.5.wav',
#  'shift0_flip-saijal-set1-clip26_3,3,2.5.wav',
#  'shift0_flip-saijal-set1-clip27_3,3,3.wav',
#  'shift0_flip-saijal-set1-clip30_3,2.5,3.wav',
#  'shift0_flip-saijal-set1-clip31_3,2.5,3.wav',
#  'shift0_flip-saijal-set1-clip33_3,2.5,3.wav',
#  'shift0_flip-saijal-set1-clip36_3,3,3.wav',
#  'shift0_flip-saijal-set1-clip40_3,2.5,3.wav',
#  'shift0_flip-saijal-set1-clip51_3,2.5,3.wav',
#  'shift0_flip-saijal-set1-clip7_2.5,3,3.wav',
#  'shift0_flip-saijal-set1-clip8_2.5,3,3.wav',
#  'shift0_flip-saijal-set2-clip10_2.5,3,3.wav',
#  'shift0_flip-saijal-set2-clip40_3,3,3.wav',
#  'shift0_flip-saijal-set2-clip44_2.5,3,3.wav',
#  'shift0_flip-saijal-set3-clip10_3,3,3.wav',
#  'shift0_flip-saijal-set3-clip13_3,3,3.wav',
#  'shift0_flip-saijal-set3-clip14_3,3,2.5.wav',
#  'shift0_flip-saijal-set3-clip15_3,3,2.5.wav',
#  'shift0_flip-saijal-set3-clip17_3,3,2.5.wav',
#  'shift0_flip-saijal-set3-clip18_3,3,3.wav',
#  'shift0_flip-saijal-set3-clip2_2.5,3,3.wav',
#  'shift0_flip-saijal-set3-clip34_3,3,2.5.wav',
#  'shift0_flip-saijal-set3-clip4_3,3,2.5.wav',
#  'shift0_flip-saijal-set3-clip50_2.5,3,3.wav',
#  'shift0_flip-saijal-set3-clip5_3,2.5,3.wav',
#  'shift0_flip-saijal-set3-clip6_3,3,3.wav',
#  'shift0_flip-saijal-set3-clip7_3,2.5,3.wav',
#  'shift0_flip-saijal-set3-clip9_3,3,3.wav',
#  'shift0_flip-saijal-set4-clip23_3,3,3.wav',
#  'shift0_flip-saijal-set4-clip24_3,3,3.wav',
#  'shift0_flip-saijal-set4-clip25_3,3,3.wav',
#  'shift0_flip-saijal-set4-clip26_3,3,3.wav',
#  'shift0_flip-saijal-set4-clip30_3,3,3.wav',
#  'shift0_flip-saijal-set4-clip31_3,3,2.5.wav',
#  'shift0_flip-saijal-set5-clip24_3,3,2.5.wav',
#  'shift0_flip-saijal-set5-clip37_3,3,2.5.wav',
#  'shift0_flip-saijal-set5-clip7_3,3,2.5.wav',
#  'shift0_flip-saijal-set6-clip33_3,3,2.5.wav',
#  'shift0_flip-saijal-set6-clip34_2.5,3,3.wav',
#  'shift0_flip-saijal-set6-clip35_3,3,3.wav',
#  'shift0_flip-saijal-set6-clip38_3,3,3.wav',
#  'shift0_flip-saijal-set6-clip39_3,3,3.wav',
#  'shift1-rahul-brian-clip1_3,3,3.wav',
#  'shift1-rahul-brian-clip3_3,3,2.5.wav',
#  'shift1-rahul-brian-clip5_3,3,3.wav',
#  'shift1-rahul-clip108_3,3,2.5.wav',
#  'shift1-rahul-clip114_3,2.5,3.wav',
#  'shift1-rahul-clip176_3,2.5,3.wav',
#  'shift1-rahul-clip196_3,3,2.5.wav',
#  'shift1-rahul-clip197_3,3,3.wav',
#  'shift1-rahul-clip198_3,3,3.wav',
#  'shift1-rahul-clip199_3,3,3.wav',
#  'shift1-rahul-clip201_3,3,3.wav',
#  'shift1-rahul-clip202_3,3,3.wav',
#  'shift1-rahul-clip203_3,3,3.wav',
#  'shift1-rahul-clip204_3,3,3.wav',
#  'shift1-rahul-clip205_3,3,3.wav',
#  'shift1-rahul-clip206_3,3,3.wav',
#  'shift1-rahul-clip220_3,2.5,3.wav',
#  'shift1-rahul-clip227_3,2.5,3.wav',
#  'shift1-rahul-clip250_3,3,2.5.wav',
#  'shift1-rahul-clip251_3,3,2.5.wav',
#  'shift1-rahul-clip252_3,3,2.5.wav',
#  'shift1-rahul-clip254_3,2.5,3.wav',
#  'shift1-rahul-clip27_3,3,3.wav',
#  'shift1-rahul-clip281_3,3,2.5.wav',
#  'shift1-rahul-clip291_3,3,2.5.wav',
#  'shift1-rahul-clip302_3,3,2.5.wav',
#  'shift1-rahul-clip329_3,3,3.wav',
#  'shift1-rahul-clip330_3,3,3.wav',
#  'shift1-rahul-clip331_3,3,2.5.wav',
#  'shift1-rahul-clip332_3,3,2.5.wav',
#  'shift1-rahul-clip333_3,3,2.5.wav',
#  'shift1-rahul-clip334_3,3,3.wav',
#  'shift1-rahul-clip335_3,3,3.wav',
#  'shift1-rahul-clip342_3,3,2.5.wav',
#  'shift1-rahul-clip353_2.5,3,3.wav',
#  'shift1-rahul-clip355_3,3,3.wav',
#  'shift1-rahul-clip361_3,2.5,3.wav',
#  'shift1-rahul-clip395_3,3,2.5.wav',
#  'shift1-rahul-clip397_2.5,3,3.wav',
#  'shift1-rahul-clip398_3,3,3.wav',
#  'shift1-rahul-clip401_3,2.5,3.wav',
#  'shift1-rahul-clip416_2.5,3,3.wav',
#  'shift1-rahul-clip448_3,3,2.5.wav',
#  'shift1-rahul-clip456_3,3,2.5.wav',
#  'shift1-rahul-clip458_3,3,2.5.wav',
#  'shift1-rahul-clip45_3,3,3.wav',
#  'shift1-rahul-clip46_3,3,2.5.wav',
#  'shift1-rahul-clip470_3,3,2.5.wav',
#  'shift1-rahul-clip47_3,3,2.5.wav',
#  'shift1-rahul-clip495_3,3,2.5.wav',
#  'shift1-rahul-clip498_3,2.5,3.wav',
#  'shift1-rahul-clip511_3,2.5,3.wav',
#  'shift1-rahul-clip553_2.5,3,3.wav',
#  'shift1-rahul-clip556_3,3,2.5.wav',
#  'shift1-rahul-clip560_3,3,2.5.wav',
#  'shift1-rahul-clip572_3,3,3.wav',
#  'shift1-rahul-clip591_3,3,3.wav',
#  'shift1-rahul-clip593_3,3,3.wav',
#  'shift1-rahul-clip595_3,2.5,3.wav',
#  'shift1-rahul-clip596_3,3,2.5.wav',
#  'shift1-rahul-clip597_3,3,3.wav',
#  'shift1-rahul-clip598_3,2.5,3.wav',
#  'shift1-rahul-clip599_3,3,3.wav',
#  'shift1-rahul-clip5_3,3,3.wav',
#  'shift1-rahul-clip600_3,3,3.wav',
#  'shift1-rahul-clip601_3,3,3.wav',
#  'shift1-rahul-clip603_3,3,3.wav',
#  'shift1-rahul-clip66_3,2.5,3.wav',
#  'shift1-rahul-clip67_3,3,2.5.wav',
#  'shift1-rahul-clip68_3,3,3.wav',
#  'shift1-rahul-clip72_3,3,3.wav',
#  'shift1-rahul-clip7_3,3,3.wav',
#  'shift1-rahul-clip84_3,3,3.wav',
#  'shift1-rahul-clip85_3,3,3.wav',
#  'shift1-rahul-clip88_3,3,2.5.wav',
#  'shift1-rahul-gang-clip1_3,3,2.5.wav',
#  'shift1-rahul-gang-clip2_3,3,3.wav',
#  'shift1-rahul-gang-clip4_3,3,2.5.wav',
#  'shift1-rahul-gang-clip5_3,3,3.wav',
#  'shift1-rahul-habits-clip4_3,2.5,3.wav',
#  'shift1-rahul-habits-clip5_3,3,3.wav',
#  'shift1-rahul-habits-clip6_3,3,3.wav',
#  'shift1-rahul-humor-clip3_3,3,3.wav',
#  'shift1-rahul-questions-clip1_3,3,3.wav',
#  'shift1-rahul-questions-clip3_3,3,2.8.wav',
#  'shift1-rahul-questions-clip7_2.5,3,3.wav',
#  'shift1-ravina-set1-clip28_3,2.5,3.wav',
#  'shift1-ravina-set1-clip42_3,2.5,3.wav',
#  'shift1-ravina-set1-clip47_3,3,2.5.wav',
#  'shift1-ravina-set2-clip30_3,3,3.wav',
#  'shift1-ravina-set2-clip41_2.5,3,3.wav',
#  'shift1-ravina-set3-clip10_2.5,3,3.wav',
#  'shift1-ravina-set3-clip25_3,3,2.5.wav',
#  'shift1-ravina-set3-clip28_3,3,3.wav',
#  'shift1-ravina-set3-clip29_3,3,3.wav',
#  'shift1-ravina-set3-clip31_2.5,3,3.wav',
#  'shift1-ravina-set3-clip33_3,3,3.wav',
#  'shift1-ravina-set3-clip36_3,3,3.wav',
#  'shift1-ravina-set3-clip37_3,3,2.5.wav',
#  'shift1-ravina-set3-clip46_3,3,2.5.wav',
#  'shift1-ravina-set3-clip47_3,3,2.5.wav',
#  'shift1-ravina-set4-clip26_2.5,3,3.wav',
#  'shift1-ravina-set4-clip28_3,2.5,3.wav',
#  'shift1-ravina-set4-clip29_2.5,3,3.wav',
#  'shift1-ravina-set4-clip33_2.5,3,3.wav',
#  'shift1-ravina-set4-clip61_3,2.5,3.wav',
#  'shift1-ravina-set4-clip62_2.5,3,3.wav',
#  'shift1-ravina-set4-clip63_3,3,3.wav',
#  'shift1-ravina-set4-clip66_2.5,3,3.wav',
#  'shift1-ravina-set4-clip67_3,3,3.wav',
#  'shift1-ravina-set4-clip70_3,3,3.wav',
#  'shift1-ravina-set4-clip72_3,3,2.5.wav',
#  'shift1-ravina-set4-clip86_2.5,3,3.wav',
#  'shift1-saijal-set1-clip22_3,2.5,3.wav',
#  'shift1-saijal-set1-clip23_3,3,2.5.wav',
#  'shift1-saijal-set1-clip24_3,3,2.5.wav',
#  'shift1-saijal-set1-clip26_3,3,2.5.wav',
#  'shift1-saijal-set1-clip27_3,3,3.wav',
#  'shift1-saijal-set1-clip30_3,2.5,3.wav',
#  'shift1-saijal-set1-clip31_3,2.5,3.wav',
#  'shift1-saijal-set1-clip33_3,2.5,3.wav',
#  'shift1-saijal-set1-clip36_3,3,3.wav',
#  'shift1-saijal-set1-clip40_3,2.5,3.wav',
#  'shift1-saijal-set1-clip51_3,2.5,3.wav',
#  'shift1-saijal-set1-clip7_2.5,3,3.wav',
#  'shift1-saijal-set1-clip8_2.5,3,3.wav',
#  'shift1-saijal-set2-clip10_2.5,3,3.wav',
#  'shift1-saijal-set2-clip40_3,3,3.wav',
#  'shift1-saijal-set2-clip44_2.5,3,3.wav',
#  'shift1-saijal-set3-clip10_3,3,3.wav',
#  'shift1-saijal-set3-clip13_3,3,3.wav',
#  'shift1-saijal-set3-clip14_3,3,2.5.wav',
#  'shift1-saijal-set3-clip15_3,3,2.5.wav',
#  'shift1-saijal-set3-clip17_3,3,2.5.wav',
#  'shift1-saijal-set3-clip18_3,3,3.wav',
#  'shift1-saijal-set3-clip2_2.5,3,3.wav',
#  'shift1-saijal-set3-clip34_3,3,2.5.wav',
#  'shift1-saijal-set3-clip4_3,3,2.5.wav',
#  'shift1-saijal-set3-clip50_2.5,3,3.wav',
#  'shift1-saijal-set3-clip5_3,2.5,3.wav',
#  'shift1-saijal-set3-clip6_3,3,3.wav',
#  'shift1-saijal-set3-clip7_3,2.5,3.wav',
#  'shift1-saijal-set3-clip9_3,3,3.wav',
#  'shift1-saijal-set4-clip23_3,3,3.wav',
#  'shift1-saijal-set4-clip24_3,3,3.wav',
#  'shift1-saijal-set4-clip25_3,3,3.wav',
#  'shift1-saijal-set4-clip26_3,3,3.wav',
#  'shift1-saijal-set4-clip30_3,3,3.wav',
#  'shift1-saijal-set4-clip31_3,3,2.5.wav',
#  'shift1-saijal-set5-clip24_3,3,2.5.wav',
#  'shift1-saijal-set5-clip37_3,3,2.5.wav',
#  'shift1-saijal-set5-clip7_3,3,2.5.wav',
#  'shift1-saijal-set6-clip33_3,3,2.5.wav',
#  'shift1-saijal-set6-clip34_2.5,3,3.wav',
#  'shift1-saijal-set6-clip35_3,3,3.wav',
#  'shift1-saijal-set6-clip38_3,3,3.wav',
#  'shift1-saijal-set6-clip39_3,3,3.wav',
#  'shift1_flip-rahul-brian-clip1_3,3,3.wav',
#  'shift1_flip-rahul-brian-clip3_3,3,2.5.wav',
#  'shift1_flip-rahul-brian-clip5_3,3,3.wav',
#  'shift1_flip-rahul-clip108_3,3,2.5.wav',
#  'shift1_flip-rahul-clip114_3,2.5,3.wav',
#  'shift1_flip-rahul-clip176_3,2.5,3.wav',
#  'shift1_flip-rahul-clip196_3,3,2.5.wav',
#  'shift1_flip-rahul-clip197_3,3,3.wav',
#  'shift1_flip-rahul-clip198_3,3,3.wav',
#  'shift1_flip-rahul-clip199_3,3,3.wav',
#  'shift1_flip-rahul-clip201_3,3,3.wav',
#  'shift1_flip-rahul-clip202_3,3,3.wav',
#  'shift1_flip-rahul-clip203_3,3,3.wav',
#  'shift1_flip-rahul-clip204_3,3,3.wav',
#  'shift1_flip-rahul-clip205_3,3,3.wav',
#  'shift1_flip-rahul-clip206_3,3,3.wav',
#  'shift1_flip-rahul-clip220_3,2.5,3.wav',
#  'shift1_flip-rahul-clip227_3,2.5,3.wav',
#  'shift1_flip-rahul-clip250_3,3,2.5.wav',
#  'shift1_flip-rahul-clip251_3,3,2.5.wav',
#  'shift1_flip-rahul-clip252_3,3,2.5.wav',
#  'shift1_flip-rahul-clip254_3,2.5,3.wav',
#  'shift1_flip-rahul-clip27_3,3,3.wav',
#  'shift1_flip-rahul-clip281_3,3,2.5.wav',
#  'shift1_flip-rahul-clip291_3,3,2.5.wav',
#  'shift1_flip-rahul-clip302_3,3,2.5.wav',
#  'shift1_flip-rahul-clip329_3,3,3.wav',
#  'shift1_flip-rahul-clip330_3,3,3.wav',
#  'shift1_flip-rahul-clip331_3,3,2.5.wav',
#  'shift1_flip-rahul-clip332_3,3,2.5.wav',
#  'shift1_flip-rahul-clip333_3,3,2.5.wav',
#  'shift1_flip-rahul-clip334_3,3,3.wav',
#  'shift1_flip-rahul-clip335_3,3,3.wav',
#  'shift1_flip-rahul-clip342_3,3,2.5.wav',
#  'shift1_flip-rahul-clip353_2.5,3,3.wav',
#  'shift1_flip-rahul-clip355_3,3,3.wav',
#  'shift1_flip-rahul-clip361_3,2.5,3.wav',
#  'shift1_flip-rahul-clip395_3,3,2.5.wav',
#  'shift1_flip-rahul-clip397_2.5,3,3.wav',
#  'shift1_flip-rahul-clip398_3,3,3.wav',
#  'shift1_flip-rahul-clip401_3,2.5,3.wav',
#  'shift1_flip-rahul-clip416_2.5,3,3.wav',
#  'shift1_flip-rahul-clip448_3,3,2.5.wav',
#  'shift1_flip-rahul-clip456_3,3,2.5.wav',
#  'shift1_flip-rahul-clip458_3,3,2.5.wav',
#  'shift1_flip-rahul-clip45_3,3,3.wav',
#  'shift1_flip-rahul-clip46_3,3,2.5.wav',
#  'shift1_flip-rahul-clip470_3,3,2.5.wav',
#  'shift1_flip-rahul-clip47_3,3,2.5.wav',
#  'shift1_flip-rahul-clip495_3,3,2.5.wav',
#  'shift1_flip-rahul-clip498_3,2.5,3.wav',
#  'shift1_flip-rahul-clip511_3,2.5,3.wav',
#  'shift1_flip-rahul-clip553_2.5,3,3.wav',
#  'shift1_flip-rahul-clip556_3,3,2.5.wav',
#  'shift1_flip-rahul-clip560_3,3,2.5.wav',
#  'shift1_flip-rahul-clip572_3,3,3.wav',
#  'shift1_flip-rahul-clip591_3,3,3.wav',
#  'shift1_flip-rahul-clip593_3,3,3.wav',
#  'shift1_flip-rahul-clip595_3,2.5,3.wav',
#  'shift1_flip-rahul-clip596_3,3,2.5.wav',
#  'shift1_flip-rahul-clip597_3,3,3.wav',
#  'shift1_flip-rahul-clip598_3,2.5,3.wav',
#  'shift1_flip-rahul-clip599_3,3,3.wav',
#  'shift1_flip-rahul-clip5_3,3,3.wav',
#  'shift1_flip-rahul-clip600_3,3,3.wav',
#  'shift1_flip-rahul-clip601_3,3,3.wav',
#  'shift1_flip-rahul-clip603_3,3,3.wav',
#  'shift1_flip-rahul-clip66_3,2.5,3.wav',
#  'shift1_flip-rahul-clip67_3,3,2.5.wav',
#  'shift1_flip-rahul-clip68_3,3,3.wav',
#  'shift1_flip-rahul-clip72_3,3,3.wav',
#  'shift1_flip-rahul-clip7_3,3,3.wav',
#  'shift1_flip-rahul-clip84_3,3,3.wav',
#  'shift1_flip-rahul-clip85_3,3,3.wav',
#  'shift1_flip-rahul-clip88_3,3,2.5.wav',
#  'shift1_flip-rahul-gang-clip1_3,3,2.5.wav',
#  'shift1_flip-rahul-gang-clip2_3,3,3.wav',
#  'shift1_flip-rahul-gang-clip4_3,3,2.5.wav',
#  'shift1_flip-rahul-gang-clip5_3,3,3.wav',
#  'shift1_flip-rahul-habits-clip4_3,2.5,3.wav',
#  'shift1_flip-rahul-habits-clip5_3,3,3.wav',
#  'shift1_flip-rahul-habits-clip6_3,3,3.wav',
#  'shift1_flip-rahul-humor-clip3_3,3,3.wav',
#  'shift1_flip-rahul-questions-clip1_3,3,3.wav',
#  'shift1_flip-rahul-questions-clip3_3,3,2.8.wav',
#  'shift1_flip-rahul-questions-clip7_2.5,3,3.wav',
#  'shift1_flip-ravina-set1-clip28_3,2.5,3.wav',
#  'shift1_flip-ravina-set1-clip42_3,2.5,3.wav',
#  'shift1_flip-ravina-set1-clip47_3,3,2.5.wav',
#  'shift1_flip-ravina-set2-clip30_3,3,3.wav',
#  'shift1_flip-ravina-set2-clip41_2.5,3,3.wav',
#  'shift1_flip-ravina-set3-clip10_2.5,3,3.wav',
#  'shift1_flip-ravina-set3-clip25_3,3,2.5.wav',
#  'shift1_flip-ravina-set3-clip28_3,3,3.wav',
#  'shift1_flip-ravina-set3-clip29_3,3,3.wav',
#  'shift1_flip-ravina-set3-clip31_2.5,3,3.wav',
#  'shift1_flip-ravina-set3-clip33_3,3,3.wav',
#  'shift1_flip-ravina-set3-clip36_3,3,3.wav',
#  'shift1_flip-ravina-set3-clip37_3,3,2.5.wav',
#  'shift1_flip-ravina-set3-clip46_3,3,2.5.wav',
#  'shift1_flip-ravina-set3-clip47_3,3,2.5.wav',
#  'shift1_flip-ravina-set4-clip26_2.5,3,3.wav',
#  'shift1_flip-ravina-set4-clip28_3,2.5,3.wav',
#  'shift1_flip-ravina-set4-clip29_2.5,3,3.wav',
#  'shift1_flip-ravina-set4-clip33_2.5,3,3.wav',
#  'shift1_flip-ravina-set4-clip61_3,2.5,3.wav',
#  'shift1_flip-ravina-set4-clip62_2.5,3,3.wav',
#  'shift1_flip-ravina-set4-clip63_3,3,3.wav',
#  'shift1_flip-ravina-set4-clip66_2.5,3,3.wav',
#  'shift1_flip-ravina-set4-clip67_3,3,3.wav',
#  'shift1_flip-ravina-set4-clip70_3,3,3.wav',
#  'shift1_flip-ravina-set4-clip72_3,3,2.5.wav',
#  'shift1_flip-ravina-set4-clip86_2.5,3,3.wav',
#  'shift1_flip-saijal-set1-clip22_3,2.5,3.wav',
#  'shift1_flip-saijal-set1-clip23_3,3,2.5.wav',
#  'shift1_flip-saijal-set1-clip24_3,3,2.5.wav',
#  'shift1_flip-saijal-set1-clip26_3,3,2.5.wav',
#  'shift1_flip-saijal-set1-clip27_3,3,3.wav',
#  'shift1_flip-saijal-set1-clip30_3,2.5,3.wav',
#  'shift1_flip-saijal-set1-clip31_3,2.5,3.wav',
#  'shift1_flip-saijal-set1-clip33_3,2.5,3.wav',
#  'shift1_flip-saijal-set1-clip36_3,3,3.wav',
#  'shift1_flip-saijal-set1-clip40_3,2.5,3.wav',
#  'shift1_flip-saijal-set1-clip51_3,2.5,3.wav',
#  'shift1_flip-saijal-set1-clip7_2.5,3,3.wav',
#  'shift1_flip-saijal-set1-clip8_2.5,3,3.wav',
#  'shift1_flip-saijal-set2-clip10_2.5,3,3.wav',
#  'shift1_flip-saijal-set2-clip40_3,3,3.wav',
#  'shift1_flip-saijal-set2-clip44_2.5,3,3.wav',
#  'shift1_flip-saijal-set3-clip10_3,3,3.wav',
#  'shift1_flip-saijal-set3-clip13_3,3,3.wav',
#  'shift1_flip-saijal-set3-clip14_3,3,2.5.wav',
#  'shift1_flip-saijal-set3-clip15_3,3,2.5.wav',
#  'shift1_flip-saijal-set3-clip17_3,3,2.5.wav',
#  'shift1_flip-saijal-set3-clip18_3,3,3.wav',
#  'shift1_flip-saijal-set3-clip2_2.5,3,3.wav',
#  'shift1_flip-saijal-set3-clip34_3,3,2.5.wav',
#  'shift1_flip-saijal-set3-clip4_3,3,2.5.wav',
#  'shift1_flip-saijal-set3-clip50_2.5,3,3.wav',
#  'shift1_flip-saijal-set3-clip5_3,2.5,3.wav',
#  'shift1_flip-saijal-set3-clip6_3,3,3.wav',
#  'shift1_flip-saijal-set3-clip7_3,2.5,3.wav',
#  'shift1_flip-saijal-set3-clip9_3,3,3.wav',
#  'shift1_flip-saijal-set4-clip23_3,3,3.wav',
#  'shift1_flip-saijal-set4-clip24_3,3,3.wav',
#  'shift1_flip-saijal-set4-clip25_3,3,3.wav',
#  'shift1_flip-saijal-set4-clip26_3,3,3.wav',
#  'shift1_flip-saijal-set4-clip30_3,3,3.wav',
#  'shift1_flip-saijal-set4-clip31_3,3,2.5.wav',
#  'shift1_flip-saijal-set5-clip24_3,3,2.5.wav',
#  'shift1_flip-saijal-set5-clip37_3,3,2.5.wav',
#  'shift1_flip-saijal-set5-clip7_3,3,2.5.wav',
#  'shift1_flip-saijal-set6-clip33_3,3,2.5.wav',
#  'shift1_flip-saijal-set6-clip34_2.5,3,3.wav',
#  'shift1_flip-saijal-set6-clip35_3,3,3.wav',
#  'shift1_flip-saijal-set6-clip38_3,3,3.wav',
#  'shift1_flip-saijal-set6-clip39_3,3,3.wav',
#  'shift2-rahul-brian-clip1_3,3,3.wav',
#  'shift2-rahul-brian-clip3_3,3,2.5.wav',
#  'shift2-rahul-brian-clip5_3,3,3.wav',
#  'shift2-rahul-clip108_3,3,2.5.wav',
#  'shift2-rahul-clip114_3,2.5,3.wav',
#  'shift2-rahul-clip176_3,2.5,3.wav',
#  'shift2-rahul-clip196_3,3,2.5.wav',
#  'shift2-rahul-clip197_3,3,3.wav',
#  'shift2-rahul-clip198_3,3,3.wav',
#  'shift2-rahul-clip199_3,3,3.wav',
#  'shift2-rahul-clip201_3,3,3.wav',
#  'shift2-rahul-clip202_3,3,3.wav',
#  'shift2-rahul-clip203_3,3,3.wav',
#  'shift2-rahul-clip204_3,3,3.wav',
#  'shift2-rahul-clip205_3,3,3.wav',
#  'shift2-rahul-clip206_3,3,3.wav',
#  'shift2-rahul-clip220_3,2.5,3.wav',
#  'shift2-rahul-clip227_3,2.5,3.wav',
#  'shift2-rahul-clip250_3,3,2.5.wav',
#  'shift2-rahul-clip251_3,3,2.5.wav',
#  'shift2-rahul-clip252_3,3,2.5.wav',
#  'shift2-rahul-clip254_3,2.5,3.wav',
#  'shift2-rahul-clip27_3,3,3.wav',
#  'shift2-rahul-clip281_3,3,2.5.wav',
#  'shift2-rahul-clip291_3,3,2.5.wav',
#  'shift2-rahul-clip302_3,3,2.5.wav',
#  'shift2-rahul-clip329_3,3,3.wav',
#  'shift2-rahul-clip330_3,3,3.wav',
#  'shift2-rahul-clip331_3,3,2.5.wav',
#  'shift2-rahul-clip332_3,3,2.5.wav',
#  'shift2-rahul-clip333_3,3,2.5.wav',
#  'shift2-rahul-clip334_3,3,3.wav',
#  'shift2-rahul-clip335_3,3,3.wav',
#  'shift2-rahul-clip342_3,3,2.5.wav',
#  'shift2-rahul-clip353_2.5,3,3.wav',
#  'shift2-rahul-clip355_3,3,3.wav',
#  'shift2-rahul-clip361_3,2.5,3.wav',
#  'shift2-rahul-clip395_3,3,2.5.wav',
#  'shift2-rahul-clip397_2.5,3,3.wav',
#  'shift2-rahul-clip398_3,3,3.wav',
#  'shift2-rahul-clip401_3,2.5,3.wav',
#  'shift2-rahul-clip416_2.5,3,3.wav',
#  'shift2-rahul-clip448_3,3,2.5.wav',
#  'shift2-rahul-clip456_3,3,2.5.wav',
#  'shift2-rahul-clip458_3,3,2.5.wav',
#  'shift2-rahul-clip45_3,3,3.wav',
#  'shift2-rahul-clip46_3,3,2.5.wav',
#  'shift2-rahul-clip470_3,3,2.5.wav',
#  'shift2-rahul-clip47_3,3,2.5.wav',
#  'shift2-rahul-clip495_3,3,2.5.wav',
#  'shift2-rahul-clip498_3,2.5,3.wav',
#  'shift2-rahul-clip511_3,2.5,3.wav',
#  'shift2-rahul-clip553_2.5,3,3.wav',
#  'shift2-rahul-clip556_3,3,2.5.wav',
#  'shift2-rahul-clip560_3,3,2.5.wav',
#  'shift2-rahul-clip572_3,3,3.wav',
#  'shift2-rahul-clip591_3,3,3.wav',
#  'shift2-rahul-clip593_3,3,3.wav',
#  ...]

# %%
#get complete location of each file
good_files = list(map(lambda x : dir_good + '/' + x, good_files))

# %% [markdown]
# ### here we extracted out log-mel-specs of good audio clips in the form of list

# %%
#get log mel spectrograms of good_files
good_logmels = [log_mel_spec(i) for i in good_files]

# %% [markdown]
# ### then we save those log-mel-specs into a new numpy file

# %%
#store good_logmels to a numpy file
np.save("H:/spec_data2/good_logmels",good_logmels)

# %% [markdown]
# ### here we created a new dataframe to store filenames of labels of good class

# %%
#store in a dataframe
#data_good = pd.DataFrame(np.transpose([good_files,good_logmels,['good'] * len(good_files)]),columns = ['filenames','logmels''class'])
data_good = pd.DataFrame({'filenames':good_files,'class':['good'] * len(good_files)})

# %% [markdown]
# ### now we repeat the same above proceducre for bad and average audio clips

# %%
#extract list of filenames from 'bad' folder
dir_bad = "H:/original+augmented2/bad"
bad_files = [f for f in listdir(dir_bad) if isfile(join(dir_bad, f))]

# %%
#get complete location of each file
bad_files = list(map(lambda x : dir_bad + '/' + x, bad_files))

# %%
#get log mel spectrograms of bad_files
bad_logmels = [log_mel_spec(i) for i in bad_files]

# %%
#store good_logmels to a numpy file
np.save("H:/spec_data2/bad_logmels",bad_logmels)

# %%
#store in a dataframe
data_bad = pd.DataFrame({'filenames':bad_files,'class':['bad'] * len(bad_files)})

# %%
#extract list of filenames from 'avg' folder
dir_avg = "H:/original+augmented2/average"
avg_files = [f for f in listdir(dir_avg) if isfile(join(dir_avg, f))]

# %%
#get complete location of each file
avg_files = list(map(lambda x : dir_avg + '/' + x, avg_files))

# %%
#get log mel spectrograms of avg_files
avg_logmels = [log_mel_spec(i) for i in avg_files]

# %%
#store avg_logmels to a numpy file
np.save("H:/spec_data2/avg_logmels",avg_logmels)

# %%
#store in a dataframe
data_avg = pd.DataFrame({'filenames':avg_files,'class':['average'] * len(avg_files)})

# %% [markdown]
# ### now we create a final empty dataframe

# %%
#now create a final empty dataframe
data = pd.DataFrame(columns = ['filenames','class'])

# %% [markdown]
# ### in this we append all 3 dataframes of good/bad/average class

# %%
#append all 3 dataframes in 'data'
data = data.append(data_good)
data = data.append(data_bad)
data = data.append(data_avg)

# %%
data
# Out:
#                                              filenames    class
# 0    H:/original+augmented2/good/flip-rahul-brian-c...     good
# 1    H:/original+augmented2/good/flip-rahul-brian-c...     good
# 2    H:/original+augmented2/good/flip-rahul-brian-c...     good
# 3    H:/original+augmented2/good/flip-rahul-clip108...     good
# 4    H:/original+augmented2/good/flip-rahul-clip114...     good
# 5    H:/original+augmented2/good/flip-rahul-clip176...     good
# 6    H:/original+augmented2/good/flip-rahul-clip196...     good
# 7    H:/original+augmented2/good/flip-rahul-clip197...     good
# 8    H:/original+augmented2/good/flip-rahul-clip198...     good
# 9    H:/original+augmented2/good/flip-rahul-clip199...     good
# 10   H:/original+augmented2/good/flip-rahul-clip201...     good
# 11   H:/original+augmented2/good/flip-rahul-clip202...     good
# 12   H:/original+augmented2/good/flip-rahul-clip203...     good
# 13   H:/original+augmented2/good/flip-rahul-clip204...     good
# 14   H:/original+augmented2/good/flip-rahul-clip205...     good
# 15   H:/original+augmented2/good/flip-rahul-clip206...     good
# 16   H:/original+augmented2/good/flip-rahul-clip220...     good
# 17   H:/original+augmented2/good/flip-rahul-clip227...     good
# 18   H:/original+augmented2/good/flip-rahul-clip250...     good
# 19   H:/original+augmented2/good/flip-rahul-clip251...     good
# 20   H:/original+augmented2/good/flip-rahul-clip252...     good
# 21   H:/original+augmented2/good/flip-rahul-clip254...     good
# 22   H:/original+augmented2/good/flip-rahul-clip27_...     good
# 23   H:/original+augmented2/good/flip-rahul-clip281...     good
# 24   H:/original+augmented2/good/flip-rahul-clip291...     good
# 25   H:/original+augmented2/good/flip-rahul-clip302...     good
# 26   H:/original+augmented2/good/flip-rahul-clip329...     good
# 27   H:/original+augmented2/good/flip-rahul-clip330...     good
# 28   H:/original+augmented2/good/flip-rahul-clip331...     good
# 29   H:/original+augmented2/good/flip-rahul-clip332...     good
# ..                                                 ...      ...
# 800  H:/original+augmented2/average/shift3_flip-sai...  average
# 801  H:/original+augmented2/average/shift3_flip-sai...  average
# 802  H:/original+augmented2/average/shift3_flip-sai...  average
# 803  H:/original+augmented2/average/shift3_flip-sai...  average
# 804  H:/original+augmented2/average/shift3_flip-sai...  average
# 805  H:/original+augmented2/average/shift3_flip-sai...  average
# 806  H:/original+augmented2/average/shift3_flip-sai...  average
# 807  H:/original+augmented2/average/shift3_flip-sai...  average
# 808  H:/original+augmented2/average/shift3_flip-sai...  average
# 809  H:/original+augmented2/average/shift3_flip-sai...  average
# 810  H:/original+augmented2/average/shift3_flip-sai...  average
# 811  H:/original+augmented2/average/shift3_flip-sai...  average
# 812  H:/original+augmented2/average/shift3_flip-sai...  average
# 813  H:/original+augmented2/average/shift3_flip-sai...  average
# 814  H:/original+augmented2/average/shift3_flip-sai...  average
# 815  H:/original+augmented2/average/shift3_flip-sai...  average
# 816  H:/original+augmented2/average/shift3_flip-sai...  average
# 817  H:/original+augmented2/average/shift3_flip-sai...  average
# 818  H:/original+augmented2/average/shift3_flip-sai...  average
# 819  H:/original+augmented2/average/shift3_flip-sai...  average
# 820  H:/original+augmented2/average/shift3_flip-sai...  average
# 821  H:/original+augmented2/average/shift3_flip-sai...  average
# 822  H:/original+augmented2/average/shift3_flip-sai...  average
# 823  H:/original+augmented2/average/shift3_flip-sai...  average
# 824  H:/original+augmented2/average/shift3_flip-sai...  average
# 825  H:/original+augmented2/average/shift3_flip-sai...  average
# 826  H:/original+augmented2/average/shift3_flip-sai...  average
# 827  H:/original+augmented2/average/shift3_flip-sai...  average
# 828  H:/original+augmented2/average/shift3_flip-sai...  average
# 829  H:/original+augmented2/average/shift3_flip-sai...  average
#
# [3190 rows x 2 columns]

# %% [markdown]
# ### then finally we save the complete dataframe as a .csv file

# %%
#save 'data' dataframe to csv file
data.to_csv('H:/spec_data2/data.csv',index = False)
